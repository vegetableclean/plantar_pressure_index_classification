# %%
##深度学习过程中，需要制作训练集和验证集、测试集。

import os, random, shutil
def moveFile(fileDir):
        pathDir = os.listdir(fileDir)    #取图片的原始路径
        filenumber=len(pathDir)
        rate=1    #自定义抽取图片的比例，比方说100张抽10张，那就是0.1
        picknumber=int(filenumber*rate) #按照rate比例从文件夹中取一定数量图片
        sample = random.sample(pathDir, picknumber)  #随机选取picknumber数量的样本图片
        print (sample)
        for name in sample:
                shutil.move(fileDir+'/'+name, tarDir+'/'+name)
        return

if __name__ == '__main__':
    fileDir = r'H:\data_augmentation2\Right_foot\normal'    #源图片文件夹路径
    tarDir = r'H:\experiment\generation\validation\Right_foot\normal'    #移动到新的文件夹路径
    moveFile(fileDir)
# Out:
# ['right_normal (404).jpg', 'right_normal (671).jpg', 'right_normal (390).jpg', 'right_normal (134).jpg', 'right_normal (794).jpg', 'right_normal (151).jpg', 'right_normal (614).jpg', 'right_normal (460).jpg', 'right_normal (627).jpg', 'right_normal (481).jpg', 'right_normal (405).jpg', 'right_normal (573).jpg', 'right_normal (568).jpg', 'right_normal (676).jpg', 'right_normal (1).jpg', 'right_normal (732).jpg', 'right_normal (719).jpg', 'right_normal (646).jpg', 'right_normal (16).jpg', 'right_normal (87).jpg', 'right_normal (494).jpg', 'right_normal (416).jpg', 'right_normal (533).jpg', 'right_normal (312).jpg', 'right_normal (805).jpg', 'right_normal (33).jpg', 'right_normal (183).jpg', 'right_normal (224).jpg', 'right_normal (339).jpg', 'right_normal (572).jpg', 'right_normal (753).jpg', 'right_normal (570).jpg', 'right_normal (532).jpg', 'right_normal (455).jpg', 'right_normal (219).jpg', 'right_normal (367).jpg', 'right_normal (508).jpg', 'right_normal (557).jpg', 'right_normal (777).jpg', 'right_normal (179).jpg', 'right_normal (145).jpg', 'right_normal (399).jpg', 'right_normal (200).jpg', 'right_normal (232).jpg', 'right_normal (785).jpg', 'right_normal (138).jpg', 'right_normal (667).jpg', 'right_normal (724).jpg', 'right_normal (10).jpg', 'right_normal (98).jpg', 'right_normal (95).jpg', 'right_normal (599).jpg', 'right_normal (421).jpg', 'right_normal (673).jpg', 'right_normal (635).jpg', 'right_normal (340).jpg', 'right_normal (198).jpg', 'right_normal (157).jpg', 'right_normal (584).jpg', 'right_normal (385).jpg', 'right_normal (801).jpg', 'right_normal (800).jpg', 'right_normal (731).jpg', 'right_normal (216).jpg', 'right_normal (406).jpg', 'right_normal (319).jpg', 'right_normal (658).jpg', 'right_normal (30).jpg', 'right_normal (666).jpg', 'right_normal (496).jpg', 'right_normal (603).jpg', 'right_normal (52).jpg', 'right_normal (402).jpg', 'right_normal (376).jpg', 'right_normal (152).jpg', 'right_normal (739).jpg', 'right_normal (661).jpg', 'right_normal (155).jpg', 'right_normal (226).jpg', 'right_normal (377).jpg', 'right_normal (611).jpg', 'right_normal (695).jpg', 'right_normal (704).jpg', 'right_normal (316).jpg', 'right_normal (563).jpg', 'right_normal (420).jpg', 'right_normal (83).jpg', 'right_normal (457).jpg', 'right_normal (618).jpg', 'right_normal (17).jpg', 'right_normal (797).jpg', 'right_normal (215).jpg', 'right_normal (524).jpg', 'right_normal (228).jpg', 'right_normal (652).jpg', 'right_normal (520).jpg', 'right_normal (144).jpg', 'right_normal (473).jpg', 'right_normal (590).jpg', 'right_normal (123).jpg', 'right_normal (451).jpg', 'right_normal (591).jpg', 'right_normal (770).jpg', 'right_normal (54).jpg', 'right_normal (620).jpg', 'right_normal (517).jpg', 'right_normal (772).jpg', 'right_normal (108).jpg', 'right_normal (313).jpg', 'right_normal (736).jpg', 'right_normal (586).jpg', 'right_normal (217).jpg', 'right_normal (115).jpg', 'right_normal (795).jpg', 'right_normal (490).jpg', 'right_normal (720).jpg', 'right_normal (391).jpg', 'right_normal (88).jpg', 'right_normal (292).jpg', 'right_normal (231).jpg', 'right_normal (213).jpg', 'right_normal (489).jpg', 'right_normal (415).jpg', 'right_normal (780).jpg', 'right_normal (315).jpg', 'right_normal (64).jpg', 'right_normal (109).jpg', 'right_normal (461).jpg', 'right_normal (8).jpg', 'right_normal (208).jpg', 'right_normal (751).jpg', 'right_normal (239).jpg', 'right_normal (636).jpg', 'right_normal (355).jpg', 'right_normal (259).jpg', 'right_normal (260).jpg', 'right_normal (436).jpg', 'right_normal (375).jpg', 'right_normal (242).jpg', 'right_normal (281).jpg', 'right_normal (476).jpg', 'right_normal (597).jpg', 'right_normal (470).jpg', 'right_normal (127).jpg', 'right_normal (691).jpg', 'right_normal (575).jpg', 'right_normal (760).jpg', 'right_normal (379).jpg', 'right_normal (101).jpg', 'right_normal (559).jpg', 'right_normal (665).jpg', 'right_normal (248).jpg', 'right_normal (185).jpg', 'right_normal (628).jpg', 'right_norma ...
